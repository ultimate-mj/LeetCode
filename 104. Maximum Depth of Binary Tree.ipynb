# %% [markdown]
# # 104. Maximum Depth of Binary Tree
#
# ## Question.
#
# Given the root of a binary tree, return its maximum depth.
#
# A binary tree's maximum depth is the number of nodes along the longest path from the root node down to the farthest leaf node.
#
# ## Example.
#
# ![image.png](attachment:image.png)
#
# Input: root = [3,9,20,null,null,15,7]
#
# Output: 3

# %% [markdown]
# ## My Solution
#
# `Runtime 18ms Beats 98.4%` `Memory 16.8MB Beats 5.60%`
#
# `Runtime 37ms Beats 10.41%` `Memory 16.9MB Beats 5.60%`
#
# idea:
# - Use given algorithm in `structures/trees/programmers/18, 19. Binary Trees`
# - But I had to add `if` `else` part

# %%
class Solution(object):
    def maxDepth(self, root):
        def depth(root):
            if root:
                l = depth(root.left) if root.left else 0
                r = depth(root.right) if root.right else 0
                return max(l, r) + 1
            else:
                return 0
        return depth(root)
